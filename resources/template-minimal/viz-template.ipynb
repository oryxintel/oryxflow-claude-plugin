# %% [markdown]
# # Report: <topic>
#
# Copy of `viz-template.ipynb`: rename to `viz-<topic>.ipynb` and replace
# `<topic>` plus the placeholder task names below. Loads pipeline outputs and
# analyzes them.
#
# Run `python run.py` first (or use `runLoad` below to run-and-load). Publish with
# `jupyter nbconvert` to `reports/render/` (see the oryxflow skill / CLAUDE.md).

# %%
import oryxflow
import pandas as pd
import matplotlib.pyplot as plt

import tasks
from flow import flow

# %% [markdown]
# ## Load outputs

# %%
# Load a computed task's output (run `python run.py` first).
# No argument loads the FINAL task; pass a task class for a specific one.
df = flow.outputLoad()
# df = flow.outputLoad(tasks.YourTask)

# Parameterized / multi-output: run-and-load a task for a parameter set (runs it
# if not cached); unpack saved outputs in save() order. Pass reset=True after
# editing the task's code so the cached variant recomputes. Load several variants
# to compare (e.g. region vs metro):
# out1, out2 = oryxflow.runLoad(tasks.YourTask, params={'param': 'value'})
# va = oryxflow.runLoad(tasks.YourTask, params={'param': 'A'})
# vb = oryxflow.runLoad(tasks.YourTask, params={'param': 'B'})

# %% [markdown]
# ## Analyze

# %%
df.head()

# %%
# df.plot()
